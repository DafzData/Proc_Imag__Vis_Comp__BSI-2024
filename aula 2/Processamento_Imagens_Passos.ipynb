# %% [markdown]
# PROCESSAMENTO DE IMAGENS UTILIZANDO A BIBLIOTECA SKIMAGE (Scikit-Image)

# %% [markdown]
# **1. a) Lendo e Exibindo uma Imagem:**

# %%
from skimage import io, color

#Carregar uma imagem de uma URL ou arquivo
imagem = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Carregar a imagem da pasta do colab
# imagem = io.imread('nome_do_arquivo.jpg')

# Exibir a imagem
io.imshow(imagem)
#io.show()

# Exibir as dimensões da imagem (dimensões da matriz)
print("\nDimensão da Imagem:", imagem.shape)

# Exibir a matriz de cada canal
print("\n Matriz do Canal RED da imagem: \n", imagem[:,:,0])
print("\n Matriz do Canal GREEN da imagem: \n", imagem[:,:,1])
print("\n Matriz do Canal BLUE da imagem: \n", imagem[:,:,2])
# Out:
# <ipython-input-8-7edcb7e36f43>:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem)
# Dimensão da Imagem: (512, 512, 3)
#
#  Matriz do Canal RED da imagem:
#  [[228 227 226 ... 237 218 193]
#  [228 228 227 ... 237 222 196]
#  [229 228 227 ... 235 218 190]
#  ...
#  [ 83  86  91 ... 172 177 177]
#  [ 82  86  92 ... 177 183 185]
#  [ 82  86  93 ... 175 181 184]]
#
#  Matriz do Canal GREEN da imagem:
#  [[135 134 133 ... 148 133 109]
#  [135 135 134 ... 150 136 113]
#  [137 136 135 ... 147 132 107]
#  ...
#  [ 19  22  25 ...  70  69  70]
#  [ 18  22  26 ...  73  73  75]
#  [ 18  22  27 ...  69  71  73]]
#
#  Matriz do Canal BLUE da imagem:
#  [[127 126 125 ... 114  92  65]
#  [127 127 126 ... 120 101  73]
#  [126 125 124 ... 125 105  77]
#  ...
#  [ 54  57  61 ...  83  82  80]
#  [ 53  57  62 ...  84  84  84]
#  [ 53  57  63 ...  81  82  82]]

# %% [markdown]
# **1.b) Construindo o HISTOGRAMA da Imagem:**

# %%
# Construa o histograma da imagem
from skimage import io, exposure
frequencia, valores = exposure.histogram(imagem)

#Exibir o histograma
import matplotlib.pyplot as plt

plt.plot(valores, frequencia)
plt.xlabel('Valores de Intensidade')
plt.ylabel('Frequência')
plt.title('Histograma da Imagem')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:445: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)

# %% [markdown]
# **2) Conversão para Escala de Cinza**

# %%
from skimage import io, color, img_as_ubyte

# Carregar a imagem de uma URL
#Carregar uma imagem de uma URL ou arquivo
imagem = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Converter para a escala de cinza
imagem_cinza = color.rgb2gray(imagem)
imagem_cinza = img_as_ubyte(imagem_cinza) # converte os pixels para o intervalo de 0 a 255

# Salvar a imagem na pasta do Colab ao lado
io.imsave('imagem_em_escala_de_cinza.jpg', imagem_cinza)

#Exibir a imagem
io.imshow(imagem_cinza)

# Exibir as dimensões da imagem
print("Dimensão da Imagem: ", imagem_cinza.shape)
# Out:
# <ipython-input-10-1e75b2c76aad>:15: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_cinza)
# Dimensão da Imagem:  (512, 512)

# %% [markdown]
# **3. Redimensionar a Imagem**

# %%
from skimage import io, transform, img_as_ubyte
import os

# Carregar uma imagem de uma URL ou arquivo
imagem = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Obter as dimensões da imagem
altura, largura = imagem.shape[:2] # [:2] para pegar apenas as duas primeiras dimensões
print(f"Largura: {largura}, Altura: {altura}")

#Definir a nova largura e altura (verifique a proporção da imagem original)
valor = int(input("Digite um valor para redimnesionar: "))
nova_largura = largura/valor
print("Nova Largura", nova_largura)
nova_altura = altura/valor
print("Nova Altura", nova_altura)

# Rediensionar a Imagem
imagem_redimensionada = transform.resize(imagem, (nova_altura,nova_largura))
imagem_redimensionada = img_as_ubyte(imagem_redimensionada)

# Salvar a imagem napasta do Colab
io.imsave('imagem_redimensionada.jpg', imagem_redimensionada)

# Exibir a imagem redimensionada
io.imshow(imagem_redimensionada)
# Out:
# Largura: 512, Altura: 512
# Digite um valor para redimnesionar: 20
# Nova Largura 25.6
# Nova Altura 25.6
# <ipython-input-11-4588ab1131f5>:26: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_redimensionada)

# %% [markdown]
# **4) Rotacionar a Imagem**

# %%
from skimage import io, transform, img_as_ubyte

# Carregar a imagem de uma URL
imagem = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Girar aimagem xx graus no sentido anti-horário  ou -xx graus noo sentido horário
angulo = int(input("'Digite o angulo de rotação: "))
imagem_rotacionada = transform.rotate(imagem, angulo)
imagem_rotacionada = img_as_ubyte(imagem_rotacionada)

# Salvar a imagem
io.imsave('imagem_rotacionada.jpg', imagem_rotacionada)

# Exibir a imagem rotacionada
io.imshow(imagem_rotacionada)
# Out:
# 'Digite o angulo de rotação: 90
# <ipython-input-12-4926d94793fd>:15: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_rotacionada)

# %% [markdown]
# **5) Recortar a Imagem**

# %%
from skimage import io, transform, img_as_ubyte

# Carregar a imagem de uma URL
imagem = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Definir as coordenadas da região de Interesse(ROI)
x1, y1, x2, y2 = 250, 320, 350, 380 #Exemplo de coordenadas

# Recorte a imagem para o ROI
imagem_recortada = imagem[y1:y2, x1:x2]
imagem_recortada = img_as_ubyte(imagem_recortada)

# Salvar a imagem na pasta do Colab
io.imsave('imagem_recortada.jpg', imagem_recortada)

# Exibir a imagem recortada
io.imshow(imagem_recortada)
# Out:
# <ipython-input-13-3d09b5695cf7>:17: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_recortada)

# %% [markdown]
# **6.a) Filtro Gaussiano**

# %%
from skimage import io, filters, img_as_ubyte

# Carregar a imagem de uma URL
imagem = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Aplicar o filtro Gaussiano para desfocar a imagem
imagem_f1 = filters.gaussian(imagem, sigma=5.0) #alterar o valor de sigma
imagem_f1 = img_as_ubyte(imagem_f1) # converte os pixels para o intervalo 0 a 255

# Salvar a imagem na pasta do Colab
io.imsave('imagem_com_filtro_gaussiano.jpg', imagem_f1)

# Exibir a imagem filtrada 1
io.imshow(imagem_f1)
# Out:
# <ipython-input-14-ec7ab686e52b>:14: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_f1)

# %% [markdown]
# **6.b) Filtro Sobel**

# %%
from skimage import io, filters, img_as_ubyte

# Aplicar o Filtro Sobel (para detecção de bordas na imagem em escala de cinza)
imagem_f2 = filters.sobel(imagem_cinza)
imagem_f2 = img_as_ubyte(imagem_f2)

# Salvar a imagem na pasta do Colab
io.imsave('imagem_com_filtro_Sobel.jpg', imagem_f2)

# Exibir a imagem(imagem_f2)
io.imshow(imagem_f2)
# Out:
# <ipython-input-15-95e7bb43bc15>:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_f2)

# %% [markdown]
# **7) Binarização da imagem**

# %%
from skimage import io, filters, img_as_ubyte

# Limiar com "filtro" OTSU (a partir da imagem em escala de cinza)
limiar = filters.threshold_otsu(imagem_cinza)
imagem_binarizada = imagem_cinza > limiar
# cada pixel é comparado ao limiar, se for menor vira 0, se maior vira 1

# Salvar a imagem na pasta do Colab
io.imsave('imagem_binarizada.jpg', imagem_binarizada)

# Exibir a imagem
io.imshow(imagem_binarizada)

# Exibir o Limiar
print(f"Limiar: {limiar}")
# Out:
# <ipython-input-19-84d355809602>:9: UserWarning: imagem_binarizada.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave('imagem_binarizada.jpg', imagem_binarizada)
# <ipython-input-19-84d355809602>:12: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagem_binarizada)
# Limiar: 111

# %% [markdown]
# 8.a) Equalização do Histograma da Imagem (ajuste do constraste)

# %%
import numpy as np
import matplotlib.pyplot as plt
from  skimage import io, color, exposure, img_as_ubyte

# Carregue a imagem em escala de cinza
imagem_entrada = imagem_cinza

# Ajuste o contraste usando a função equalize_hist do sckit-image (skimage)
imagem_equalizada = exposure.equalize_hist(imagem_cinza)

#Exibir a imagem de entrada e a de saída lado a lado
plt.figure(figsize=(10,5))

plt.subplot(121)
plt.title('Imagem de Entrada')
plt.imshow(imagem_entrada, cmap='gray')

plt.subplot(122)
plt.title('Imagem de Saída (ajuste de Contraste)')
plt.imshow(imagem_equalizada, cmap='gray')

plt.tight_layout()
plt.show()

# %% [markdown]
# **8.b) Histograma das Imagens de Entrada e Saída**

# %%
# Histograma das imagens
freq_entrada, valores_entrada = exposure.histogram(imagem_entrada)
freq_saida, valores_saida = exposure.histogram(imagem_equalizada)

# Exibir os histogramas
plt.figure(figsize=(10,5))

plt.subplot(121) # Histograma de ENTRADA
plt.plot(valores_entrada, freq_entrada)
plt.title('Histograma da IMagem de Entrada')
plt.xlabel('Valores de Intensidade')
plt.ylabel('Frequência')

plt.subplot(122) # HISTOGRAMA DE SAÍDA
plt.plot(valores_saida, freq_saida)
plt.title('Histograma da IMagem de SAÍDA')
plt.xlabel('Valores de Intensidade')
plt.ylabel('Frequência')

plt.tight_layout()
plt.show()

# %% [markdown]
# **9)  Canais de uma imagem RGB**

# %%
from skimage import io
# Carregue uma imagem RGB
imagem_rgb = io.imread('https://raw.githubusercontent.com/koyachi/go-lena/master/example/lena.result.jpg')

# Separar os canais de cores da imagem (R, G, B)
canal_r = imagem_rgb[:,:,0] # canal Vermellho
canal_g = imagem_rgb[:,:,1] # canal VERDE
canal_b = imagem_rgb[:,:,2] # canal AZUL

# Exibir cada canal separadamente
io.imshow(canal_r, cmap='Reds')
io.show()

io.imshow(canal_r, cmap='Greens')
io.show()

io.imshow(canal_r, cmap='Blues')
io.show()
# Out:
# <ipython-input-26-4f603bec2074>:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(canal_r, cmap='Reds')
# <ipython-input-26-4f603bec2074>:12: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# <ipython-input-26-4f603bec2074>:14: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(canal_r, cmap='Greens')
# <ipython-input-26-4f603bec2074>:15: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# <ipython-input-26-4f603bec2074>:17: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(canal_r, cmap='Blues')
# <ipython-input-26-4f603bec2074>:18: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
